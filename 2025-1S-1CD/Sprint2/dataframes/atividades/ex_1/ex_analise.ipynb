# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel("vendas_tratadas.xlsx")

# %% [markdown]
# 1. Total de vendas por loja - Agrupar por loja e somar o valor total vendido

# %%
plt.figure(figsize=(10,5))
vendas_loja = df.groupby('loja')['valor_venda'].sum()
vendas_loja.plot(kind='bar', color='red')
plt.title('Total de vendas')
plt.xlabel('Loja')
plt.ylabel('Vendas em R$')
plt.grid(True) 
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 2. Evolução mensal de vendas - Identificar sazonalidades e picos mensais

# %%
plt.figure(figsize=(10,5))
df['ano_mes'] = df['data'].dt.to_period('M')
vendas_mes = df.groupby('ano_mes')['valor_venda'].sum()
vendas_mes.plot(marker='o', linestyle='-', color='red')
plt.title('Total de Vendas')
plt.xlabel('Meses')
plt.ylabel('Número de Vendas')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# 3. Agrupar por mês e somar vendas

# %%
plt.figure(figsize=(15, 5))
vendas_mes = df.groupby('ano_mes')['valor_venda'].sum()
ax = vendas_mes.plot(kind='bar', color='red')
plt.title('Total de Vendas mensais')
plt.xlabel('Meses')
plt.ylabel('Número de Vendas')
plt.grid(True)
plt.xticks(rotation=45)

for i, v in enumerate(vendas_mes):
    ax.text(i, v + 50, f'{v:.0f}', ha='center', va='bottom', fontsize=10)

plt.legend()
plt.show()

# %% [markdown]
# 4. Produtos mais vendidos(por volume) Objetivo: saber o que mais sai no caixa

# %%
plt.figure(figsize=(10,5))
vendas_mes = df.groupby('produto')['valor_venda'].sum()
vendas_mes.plot(kind='bar', color='blue')
plt.title('Total de Vendas por Produto')
plt.xlabel('Produto')
plt.ylabel('Número de Vendas')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# 5. Comparação entre categorias. Objetivo: analisar quais categorias são mais lucrativas

# %%
plt.figure(figsize=(10,5))
vendas_por_mes = df.groupby('categoria')['valor_venda'].sum()
vendas_por_mes.plot(kind='bar', color='blue')
plt.title('Total de Vendas por Categoria')
plt.xlabel('Categoria')
plt.ylabel('Número de Vendas')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# 6. Comparação entre lojas por categoria. Objetivo: avaliar se há especialização ou foco diferente entre as lojas, com base nas categorias que mais vendem
#
# 7. Plotar como gráfico de barras empilhadas

# %%
comparacao = df.groupby(['loja', 'categoria'])['valor_unitario'].sum().reset_index()
tabela_pivot = comparacao.pivot(index='loja', columns='categoria', values='valor_unitario')
tabela_pivot.plot(kind='barh', figsize=(10,6), colormap='Set2')
plt.title('Total de Vendas por Produto')
plt.xlabel('Produto')
plt.ylabel('Número de Vendas')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()
